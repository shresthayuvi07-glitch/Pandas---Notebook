# %% [markdown]
# ## **Pandas_Condition Notebook**

# %%
import pandas as pd 
df= pd.read_csv(r"C:\Users\HP\Downloads\titanic_dataset.csv")
df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1         0       3
# 1               2         1       1
# 2               3         1       3
# 3               4         1       1
# 4               5         0       3
# ...           ...       ...     ...
# 1304         1305         0       3
# 1305         1306         1       1
# 1306         1307         0       3
# 1307         1308         0       3
# 1308         1309         0       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
# Coding
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# ### **Syntax for loc**
# **df.loc[row_condition, column_selection]**

# %% [markdown]
# ### Accessing Age above 30:

# %%
# Coding
df[df["Age"]>30]
# Out:
#       PassengerId  Survived  Pclass  \
# 1               2         1       1
# 3               4         1       1
# 4               5         0       3
# 6               7         0       1
# 11             12         1       1
# ...           ...       ...     ...
# 1295         1296         0       1
# 1298         1299         0       1
# 1302         1303         1       1
# 1305         1306         1       1
# 1306         1307         0       3
#
#                                                    Name     Sex   Age  SibSp  \
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# 6                               McCarthy, Mr. Timothy J    male  54.0      0
# 11                             Bonnell, Miss. Elizabeth  female  58.0      0
# ...

# %% [markdown]
# ### Using .loc

# %%
# Coding 
df.loc[df["Age"]>30, :]
# Out:
#       PassengerId  Survived  Pclass  \
# 1               2         1       1
# 3               4         1       1
# 4               5         0       3
# 6               7         0       1
# 11             12         1       1
# ...           ...       ...     ...
# 1295         1296         0       1
# 1298         1299         0       1
# 1302         1303         1       1
# 1305         1306         1       1
# 1306         1307         0       3
#
#                                                    Name     Sex   Age  SibSp  \
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# 6                               McCarthy, Mr. Timothy J    male  54.0      0
# 11                             Bonnell, Miss. Elizabeth  female  58.0      0
# ...

# %% [markdown]
# ### Access data to find a Passengers who has survived

# %%
# Coding 
df.loc[df["Survived"]==1, ["Name", "Age", "Survived"]]
# Out:
#                                                    Name   Age  Survived
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0         1
# 2                                Heikkinen, Miss. Laina  26.0         1
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0         1
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0         1
# 9                   Nasser, Mrs. Nicholas (Adele Achem)  14.0         1
# ...                                                 ...   ...       ...
# 1300                          Peacock, Miss. Treasteall   3.0         1
# 1301                             Naughton, Miss. Hannah   NaN         1
# 1302    Minahan, Mrs. William Edward (Lillian E Thorpe)  37.0         1
# 1303                     Henriksson, Miss. Jenny Lovisa  28.0         1
# 1305                       Oliva y Ocana, Dona. Fermina  39.0         1
#
# [494 rows x 3 columns]

# %% [markdown]
# ### Access data to find Passenger who are in first Class

# %%
# Coding 
df.loc[df["Pclass"]==1, ["Name", "Age", "Sex", "Pclass"]]
# Out:
#                                                    Name   Age     Sex  Pclass
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female       1
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female       1
# 6                               McCarthy, Mr. Timothy J  54.0    male       1
# 11                             Bonnell, Miss. Elizabeth  58.0  female       1
# 23                         Sloper, Mr. William Thompson  28.0    male       1
# ...                                                 ...   ...     ...     ...
# 1294                             Carrau, Mr. Jose Pedro  17.0    male       1
# 1295                       Frauenthal, Mr. Isaac Gerald  43.0    male       1
# 1298                         Widener, Mr. George Dunton  50.0    male       1
# 1302    Minahan, Mrs. William Edward (Lillian E Thorpe)  37.0  female       1
# 1305                       Oliva y Ocana, Dona. Fermina  39.0  female       1
#
# [323 rows x 4 columns]

# %% [markdown]
# ### Accessing data using **and condition**:

# %% [markdown]
# ### Q.1 Find out a Passenger data who are above age of 30 and has survived

# %%
# Caoding 
df.loc[(df["Age"]>30) & (df["Survived"]==1), :]
# Out:
#       PassengerId  Survived  Pclass  \
# 1               2         1       1
# 3               4         1       1
# 11             12         1       1
# 15             16         1       2
# 21             22         1       2
# ...           ...       ...     ...
# 1266         1267         1       1
# 1282         1283         1       1
# 1288         1289         1       1
# 1302         1303         1       1
# 1305         1306         1       1
#
#                                                    Name     Sex   Age  SibSp  \
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                             Bonnell, Miss. Elizabeth  female  58.0      0
# 15                     Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 21                                Beesley, Mr. Lawrence    male  34.0      0
# ...

# %% [markdown]
# ### Q.2 Find out a Passenger data whose age is above 18 or must be Female Passenger

# %%
# Coding
df.loc[(df["Age"]>25) | (df["Sex"]=="female"), :]
# Out:
#       PassengerId  Survived  Pclass  \
# 1               2         1       1
# 2               3         1       3
# 3               4         1       1
# 4               5         0       3
# 6               7         0       1
# ...           ...       ...     ...
# 1301         1302         1       3
# 1302         1303         1       1
# 1303         1304         1       3
# 1305         1306         1       1
# 1306         1307         0       3
#
#                                                    Name     Sex   Age  SibSp  \
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# 6                               McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %% [markdown]
# ### Q.3 Find out a data of Passenger who are in 3-class and is female

# %%
# Coding
df.loc[(df["Pclass"]==3) & (df["Sex"]== "female"), ["Name", "Age", "Pclass"]]
# Out:
#                                                    Name   Age  Pclass
# 2                                Heikkinen, Miss. Laina  26.0       3
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0       3
# 10                      Sandstrom, Miss. Marguerite Rut   4.0       3
# 14                 Vestrom, Miss. Hulda Amanda Adolfina  14.0       3
# 18    Vander Planke, Mrs. Julius (Emelia Maria Vande...  31.0       3
# ...                                                 ...   ...     ...
# 1274                McNamee, Mrs. Neal (Eileen O'Leary)  19.0       3
# 1299                    Riordan, Miss. Johanna Hannah""   NaN       3
# 1300                          Peacock, Miss. Treasteall   3.0       3
# 1301                             Naughton, Miss. Hannah   NaN       3
# 1303                     Henriksson, Miss. Jenny Lovisa  28.0       3
#
# [216 rows x 3 columns]

# %% [markdown]
# ### Q.4 Find out a data of Passenger who are in 3-class and is male

# %%
# Coding 
df.loc[(df["Pclass"]==3) & (df["Sex"]=="male"), ["Name", "Age", "Pclass"]]
# Out:
#                                 Name   Age  Pclass
# 0            Braund, Mr. Owen Harris  22.0       3
# 4           Allen, Mr. William Henry  35.0       3
# 5                   Moran, Mr. James   NaN       3
# 7     Palsson, Master. Gosta Leonard   2.0       3
# 12    Saundercock, Mr. William Henry  20.0       3
# ...                              ...   ...     ...
# 1290        Conlon, Mr. Thomas Henry  31.0       3
# 1304              Spector, Mr. Woolf   NaN       3
# 1306    Saether, Mr. Simon Sivertsen  38.5       3
# 1307             Ware, Mr. Frederick   NaN       3
# 1308        Peter, Master. Michael J   NaN       3
#
# [493 rows x 3 columns]

# %% [markdown]
# ### Q.5 Find out the data of female Passenger who are olde than 25

# %%
# Coding 
df.loc[(df["Age"]>25) & (df["Sex"]== "female"), ["Name", "Age", "Sex"]]
# Out:
#                                                    Name   Age     Sex
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                                Heikkinen, Miss. Laina  26.0  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0  female
# 11                             Bonnell, Miss. Elizabeth  58.0  female
# ...                                                 ...   ...     ...
# 1288  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...  48.0  female
# 1291                            Bonnell, Miss. Caroline  30.0  female
# 1302    Minahan, Mrs. William Edward (Lillian E Thorpe)  37.0  female
# 1303                     Henriksson, Miss. Jenny Lovisa  28.0  female
# 1305                       Oliva y Ocana, Dona. Fermina  39.0  female
#
# [210 rows x 3 columns]

# %% [markdown]
# ### Q.6 Find out the average age of Survival

# %%
# Coding
df.loc[df["Survived"]==1, "Age"].mean()
# Out:
# 28.93107913669065

# %% [markdown]
# ### Q.7 Find out the data of Rich passengers (Fare > 100) who survived, only find name and age

# %%
# Coding
df.loc[(df["Fare"]>100) & (df["Survived"]==1), ["Name", "Age", "Fare"]]
# Out:
#                                                 Name   Age      Fare
# 27                    Fortune, Mr. Charles Alexander  19.0  263.0000
# 31    Spencer, Mrs. William Augustus (Marie Eugenie)   NaN  146.5208
# 88                        Fortune, Miss. Mabel Helen  23.0  263.0000
# 118                         Baxter, Mr. Quigg Edmond  24.0  247.5208
# 195                             Lurette, Miss. Elise  58.0  146.5208
# ...                                              ...   ...       ...
# 1262                       Wilson, Miss. Helen Alice  31.0  134.5000
# 1266                        Bowen, Miss. Grace Scott  45.0  262.3750
# 1291                         Bonnell, Miss. Caroline  30.0  164.8667
# 1298                      Widener, Mr. George Dunton  50.0  211.5000
# 1305                    Oliva y Ocana, Dona. Fermina  39.0  108.9000
#
# [84 rows x 3 columns]

# %% [markdown]
# ### Q.8 Find out the data of the name and age of Children (<15) in 3rd class

# %%
# Coding
df.loc[(df["Age"]<15) & (df["Pclass"]==3), ["Name", "Age"]]
# Out:
#                                       Name   Age
# 7           Palsson, Master. Gosta Leonard   2.0
# 10         Sandstrom, Miss. Marguerite Rut   4.0
# 14    Vestrom, Miss. Hulda Amanda Adolfina  14.0
# 16                    Rice, Master. Eugene   2.0
# 24           Palsson, Miss. Torborg Danira   8.0
# ...                                    ...   ...
# 1251           Sage, Master. William Henry  14.5
# 1270           Asplund, Master. Carl Edgar   5.0
# 1280           Palsson, Master. Paul Folke   6.0
# 1283         Abbott, Master. Eugene Joseph  13.0
# 1300             Peacock, Miss. Treasteall   3.0
#
# [75 rows x 2 columns]

# %% [markdown]
# ### Q.9 Count passengers older than 60

# %%
# Coding
df.loc[df["Age"]>60, :].shape[0]
# Out:
# 33
